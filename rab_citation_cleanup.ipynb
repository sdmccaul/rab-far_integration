# %%
import csv
import collections
import pprint
import lxml.etree as ET
from copy import deepcopy
import json
import functools

# %%
with open('data/cleanup/venue_citations_graph.csv') as f:
    rdr = csv.reader(f)
    head = next(rdr)
    rows = [r for r in rdr]
rows
# Out:
# [['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#date',
#   '2009-09-01',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#volume',
#   '18',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://vivo.brown.edu/ontology/citation#Citation',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://www.w3.org/2002/07/owl#Thing',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://vivo.brown.edu/ontology/citation#Article',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://vivo.brown.edu/ontology/citation#Venue',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#pmcid',
#   'PMC2825685',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#hasContributor',
#   'http://vivo.brown.edu/individual/dsavitz',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#   'http://vivo.brown.edu/ontology/citation#Article',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#   'http://vivo.brown.edu/ontology/citation#Venue',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#issn',
#   '1529-0131',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#issn',
#   '0004-3591',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#authorList',
#   'Harville EW, Savitz DA, Dole N, Herring AH, Thorp JM',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#pmid',
#   '19757520',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#issue',
#   '9',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#doi',
#   '10.1089/jwh.2008.1102',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#hasVenue',
#   'http://vivo.brown.edu/individual/nebf5c5783c714f37900b9874f2535c8d',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n87311',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n21647',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n14011',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n66397',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n40404',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n38249',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n59045',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n78667',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n77989',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n8193',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n18411',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n72038',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n97680',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n0b2c0af8d1014abcac3fce09ba1287a8',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n94822',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n60158',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n33814',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n42984',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n94898',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n16214',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n61774',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n99040',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n97937',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n84694',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n4759',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n52948',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n80186',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n7050',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n70062',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n82378',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n9185',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n86467',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n21640',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n58487',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n29383',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n54295',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n36343',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#eissn',
#   '1529-0131',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://vivo.brown.edu/ontology/citation#pages',
#   '1425-33',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n52190',
#   'http://www.w3.org/2000/01/rdf-schema#label',
#   'Arthritis and rheumatism',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#date',
#   '2001-12-01',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#volume',
#   '1',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://vivo.brown.edu/ontology/citation#Citation',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://www.w3.org/2002/07/owl#Thing',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://vivo.brown.edu/ontology/citation#Article',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#   'http://vivo.brown.edu/ontology/citation#Venue',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#hasContributor',
#   'http://vivo.brown.edu/individual/fdomini',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#   'http://vivo.brown.edu/ontology/citation#Article',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#   'http://vivo.brown.edu/ontology/citation#Venue',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#issn',
#   '1534-7362',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#authorList',
#   'Chen, J. T., Domini, F., Caudek, C.',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#issue',
#   '3',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#doi',
#   '10.1167/1.3.328',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#hasVenue',
#   'http://vivo.brown.edu/individual/n12312',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-2'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n12312',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n42626',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n40711',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n54073',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n44148',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n64234',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n92519',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n3229f4d2125a41319566dcffe9e858a6',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n65996',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n25652',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n6479',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n4541',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n38446',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n45676',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n555',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n2213',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n17272',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n78123',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n95387',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n82803',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n50991',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n90282',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n85289',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n75890',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n58721',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n19929',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n65698',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/nd60d2f0aa41e4241aa13b5efa8f89c14',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n18783',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n39887',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n33305',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n44457',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n84689',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n77617',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n49780',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n9824',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n78888',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n45692',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n97129',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n99612',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n9361',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n38464',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n84658',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n47942',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n42139',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n53717',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n83377',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n77806',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n56764',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n22175',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n23015',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n75570',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n79215',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n92569',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n17593',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n62866',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n48453',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/nd14928e462e942ce808d99bf8a646670',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n43850',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n24572',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n41161',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/nd5737da30d304dd3a5996d30e8aa1acf',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n64936',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n59156',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n53001',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n58260',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n64050',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n5934',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n11004',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n20358',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n50407',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n006fcd6ead764c0eacc4acbd3e22337a',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n131bb3c8abae467689773ce58d7a5176',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n57470',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n70959',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n82092',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n87534',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n36679',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n51886',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n49961',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n29445',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n85685',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n62120',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n24918',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/nd79ef9211c0b417295ffb508ed9a2e91',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n24863',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n2013',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n169aeb2b23e74b94aa0bfe2deb79fc48',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n46328c3ef05e44e8a082b20e2f648a98',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n13223',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n42543',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n91083',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n42345',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n14124681af6440428f10d27bd2189247',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n0f22147b2573497ab94f076fabff80fa',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n61911',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n11849',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n27674',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n79788',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n42847',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n24511',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n7562',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n32041',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n17293',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n94238',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n76194',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n96625',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n44269',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n87955',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n22382',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n92074',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n79033',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/nde69111e85fc45779c29f9143b1f278a',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n85627',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n49591',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n56410',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n28056',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n21802',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/na0367f543c4c4693adcdd0ed3aea20ef',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n9330',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n89904',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/nab68aebd1629466fa278b38abe7be596',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n94222',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n90889',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n64106',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n34820',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n47287',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n5527e323da4a4ca68c68c36da31ce613',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n3c5b9cf704954424a93b9b39cdf0b7c3',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n50355',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n90734',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n84646',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n15590',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n69391',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n2413',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n60555',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n67259',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n93031',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n71653',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n43387',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n5930',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n14535',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n1100e09180a5475d896d1a6a2ec0c944',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n5730',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n96521',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n78184',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n45196',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n81983',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n4037',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n30041',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n76530',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n22670',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n25184',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n3377',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n55829',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n39169',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n44455',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n25933',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n45735',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n82465',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n91100',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n23a3ec65f38748aaac3d85cb4429df6a',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n30778',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n12312',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n22337',
# ...
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n34541',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n65880',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n57634',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n75855',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n27294',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n91760',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n47961',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n74949',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n64349',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n81724',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n90909',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n91712',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n28111',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n70704',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n63838',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n14749',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n36122',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n9719',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n91233',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n11359',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n70419',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n64928',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n28366',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n65317',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n4970',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n15524',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n62306',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n88476',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n46912',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n43843',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n34495',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n7818',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n14495',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n26553',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n4918',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n6f7ed38383a54752928574ff41011bdd',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n56467',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n98418',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n98784',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n51010',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n34046',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n72084',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n89951',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n59812',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n44849',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n61233',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n79289',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n94096',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n37892',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n40783',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n47594',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n19874',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n2408',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n43962',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n11957',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n25111',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n28860',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n480c582b5bc740ff8c58fcd0b383e8ba',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n18717',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n19524',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n6632',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n99443',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n74196',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n90431',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n57684',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n51762',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n54296',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n90369',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n65498',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n51029',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n12978',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n71580',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n20725',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n61404',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n30402',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n37200',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n32076',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ['http://vivo.brown.edu/individual/n91166',
#   'http://vivo.brown.edu/ontology/citation#venueFor',
#   'http://vivo.brown.edu/individual/n98609',
#   'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'],
#  ...]

# %%
short_ids = [ r[2] for r in rows if r[1] == 'http://vivo.brown.edu/ontology/citation#hasContributor']
','.join([ "'{}'".format(s[33:]) for s in short_ids])
# Out:
# "'dsavitz','fdomini','ssun','dwazermd','jheadiii','jwandsmd','ll7','dsavitz','gkarniad','cshu','ktkelsey','dcoustan','ssun','mbossy','jwandsmd','bsandste','mranney','wwarrenj','ktkelsey','dkielmd','johsilve','gwessel','ktkelsey','jheadiii','eupfal'"

# %%
cite_props = { r[1] for r in rows if r[1] != 'http://vivo.brown.edu/ontology/citation#venueFor'}
cite_props
# Out:
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#publishedIn',
#  'http://vivo.brown.edu/ontology/citation#url',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}

# %%
decl_props = { r[1] for r in rows if r[3] != 'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'}
decl_props
# Out:
# {'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#publishedIn',
#  'http://vivo.brown.edu/ontology/citation#url',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}

# %%
inf_props = { r[1] for r in rows if r[3] == 'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf' }
inf_props
# Out:
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}

# %%
inf_types = { r[2] for r in rows if r[3] == 'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'
            and r[1] == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}
inf_types
# Out:
# {'http://vivo.brown.edu/ontology/citation#Citation',
#  'http://www.w3.org/2002/07/owl#Thing'}

# %%
inf_types = { r[2] for r in rows if r[3] != 'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf'
            and r[1] == 'http://www.w3.org/1999/02/22-rdf-syntax-ns#type'}
inf_types
# Out:
# {'http://vivo.brown.edu/ontology/citation#Article',
#  'http://vivo.brown.edu/ontology/citation#Citation',
#  'http://vivo.brown.edu/ontology/citation#NoID',
#  'http://vivo.brown.edu/ontology/citation#Review',
#  'http://vivo.brown.edu/ontology/citation#Venue'}

# %%
limited = [ r for r in rows if r[1]== 'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType'
          and r[3] != 'http://vitro.mannlib.cornell.edu/default/vitro-kb-inf' ]
limited
# Out:
# []

# %%
cprops = collections.defaultdict(set)
for r in rows:
    cprops[r[0]].add(r[1])
print(len(cprops))
for c in cprops:
    print(c)
    pprint.pprint(cprops[c])
# Out:
# 25
# http://vivo.brown.edu/individual/n52190
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n12312
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n38511
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n79283
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n79541
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n5101
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n59735
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n3917
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n91166
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n67856
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n28550
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n2053
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#url',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n21627
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n27567
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n1814
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#publishedIn',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n16928
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n57636
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n52039
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmcid',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n17527
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#eissn',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#pmid',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n44730
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issn',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}
# http://vivo.brown.edu/individual/n32612
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#authorList',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#doi',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}

# %%
shared = set()
for c in cprops:
    if not shared:
        shared = cprops[c]
    else:
        shared &= cprops[c]
shared
# Out:
# {'http://vitro.mannlib.cornell.edu/ns/vitro/0.7#mostSpecificType',
#  'http://vivo.brown.edu/ontology/citation#date',
#  'http://vivo.brown.edu/ontology/citation#hasContributor',
#  'http://vivo.brown.edu/ontology/citation#hasVenue',
#  'http://vivo.brown.edu/ontology/citation#issue',
#  'http://vivo.brown.edu/ontology/citation#pages',
#  'http://vivo.brown.edu/ontology/citation#venueFor',
#  'http://vivo.brown.edu/ontology/citation#volume',
#  'http://www.w3.org/1999/02/22-rdf-syntax-ns#type',
#  'http://www.w3.org/2000/01/rdf-schema#label'}

# %%
crabids = { r[0]: {} for r in rows }
id_props = { 'http://www.w3.org/2000/01/rdf-schema#label',
            'http://vivo.brown.edu/ontology/citation#doi',
            'http://vivo.brown.edu/ontology/citation#pmid',
           'http://vivo.brown.edu/ontology/citation#url'}
for r in rows:
    if r[1] in id_props:
        crabids[r[0]][r[1][r[1].index('#')+1:]] = r[2]
crabids
# Out:
# {'http://vivo.brown.edu/individual/n52190': {'pmid': '19757520',
#   'doi': '10.1089/jwh.2008.1102',
#   'label': 'Arthritis and rheumatism'},
#  'http://vivo.brown.edu/individual/n12312': {'doi': '10.1167/1.3.328',
#   'label': 'Journal of Vision'},
#  'http://vivo.brown.edu/individual/n38511': {'pmid': '20297818',
#   'doi': '10.1021/ja1009629',
#   'label': 'J. Appl. Phys.'},
#  'http://vivo.brown.edu/individual/n79283': {'pmid': '18716592',
#   'doi': '10.1120/jacmp.v9i3.2775',
#   'label': 'Brachytherapy'},
#  'http://vivo.brown.edu/individual/n79541': {'doi': '10.1130/g24382a.1',
#   'label': 'Science'},
#  'http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32': {'doi': '10.1158/1538-7445.am2013-890',
#   'label': "Alzheimer's & Dementia"},
#  'http://vivo.brown.edu/individual/n5101': {'doi': '10.1109/jproc.2014.2298231',
#   'label': 'RF and Microwave Hardware Challenges for Future Radio Spectrum Access'},
#  'http://vivo.brown.edu/individual/n59735': {'pmid': '20696650',
#   'doi': '10.1093/aje/kwq181',
#   'label': 'Paediatric and perinatal epidemiology'},
#  'http://vivo.brown.edu/individual/n3917': {'doi': '10.1016/j.parco.2003.05.020',
#   'label': 'Computer Methods in Applied Mechanics and Engineering'},
#  'http://vivo.brown.edu/individual/n91166': {'doi': '10.1137/100791002',
#   'label': 'Journal of Computational Physics'},
#  'http://vivo.brown.edu/individual/n67856': {'pmid': '11313923',
#   'doi': '10.1038/sj.onc.1204302',
#   'label': 'Human Genetics'},
#  'http://vivo.brown.edu/individual/n28550': {'pmid': '22301123',
#   'doi': '10.2337/dc11-1687',
#   'label': 'Neuropsychologia'},
#  'http://vivo.brown.edu/individual/n2053': {'pmid': '23426846',
#   'doi': '10.1002/anie.201300276',
#   'label': 'Nanoscale'},
#  'http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee': {'url': 'http://www.journals.uchicago.edu/doi/full/10.1086/692251',
#   'label': 'Speculum'},
#  'http://vivo.brown.edu/individual/n21627': {'pmid': '9462667',
#   'doi': '10.1002/hep.510270243',
#   'label': 'Hepatitis B virus mutants associated with 3TC and famciclovir administration are replication defective.'},
#  'http://vivo.brown.edu/individual/n27567': {'doi': '10.1016/j.jde.2009.06.010',
#   'label': 'SIAM Journal on Mathematical Analysis'},
#  'http://vivo.brown.edu/individual/n1814': {'pmid': '28874943',
#   'doi': '10.5811/westjem.2017.6.34849',
#   'label': 'Violence'},
#  'http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c': {'pmid': '16859793',
#   'doi': '10.1016/j.humov.2006.05.001',
#   'label': 'Philosophical Topics'},
#  'http://vivo.brown.edu/individual/n16928': {'pmid': '19029194',
#   'doi': '10.1093/carcin/bgn261',
#   'label': 'Base excision repair genes and risk of lung cancer among San Francisco Bay Area Latinos and African-Americans.'},
#  'http://vivo.brown.edu/individual/n57636': {'pmid': '18065599',
#   'label': 'Advances in prostaglandin, thromboxane, and leukotriene research'},
#  'http://vivo.brown.edu/individual/n52039': {'doi': '10.4064/aa137-3-8',
#   'label': 'Mathematische Annalen'},
#  'http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905': {'pmid': '26590170',
#   'doi': '10.1093/molehr/gav064',
#   'label': 'International Journal of Heat and Mass Transfer'},
#  'http://vivo.brown.edu/individual/n17527': {'pmid': '10923619',
#   'label': 'Head &amp; neck'},
#  'http://vivo.brown.edu/individual/n44730': {'doi': '10.1002/2014gl059861',
#   'label': 'Earth Moon Planet'},
#  'http://vivo.brown.edu/individual/n32612': {'doi': '10.14778/1920841.1921000',
#   'label': 'Database-support for continuous prediction queries over streaming data'}}

# %%
for c in crabids:
    if not set(['doi','pmid']) & set(crabids[c].keys()):
        print(crabids[c])
# Out:
# {'url': 'http://www.journals.uchicago.edu/doi/full/10.1086/692251', 'label': 'Speculum'}

# %%
labels = collections.defaultdict(set)
for r in rows:
    if r[1] == 'http://www.w3.org/2000/01/rdf-schema#label':
        labels[r[0]].add(r[2])
for l in labels:
    if len(labels[l]) > 1:
        print(l)
        print("\t", labels[l])
# Out:
# http://vivo.brown.edu/individual/n5101
# 	 {'RF and Microwave Hardware Challenges for Future Radio Spectrum Access', 'The 2005 IEEE Annual Conference Wireless and Micrwave Technology, 2005.'}
# http://vivo.brown.edu/individual/n21627
# 	 {'The Johns Hopkins medical journal', 'Hepatitis B virus mutants associated with 3TC and famciclovir administration are replication defective.'}
# http://vivo.brown.edu/individual/n16928
# 	 {'Base excision repair genes and risk of lung cancer among San Francisco Bay Area Latinos and African-Americans.', 'Chemico-biological interactions'}
# http://vivo.brown.edu/individual/n57636
# 	 {'Advances in prostaglandin, thromboxane, and leukotriene research', 'Calcium intake and hip fracture risk in men and women: a meta-analysis of prospective cohort studies and randomized controlled trials.'}
# http://vivo.brown.edu/individual/n44730
# 	 {'Recent Ice Ages on Mars: The role of radiatively active clouds and cloud microphysics', 'Earth Moon Planet'}
# http://vivo.brown.edu/individual/n32612
# 	 {'Biocomputing 2012', 'Database-support for continuous prediction queries over streaming data'}

# %%
for l in labels:
    if len(labels[l]) < 2:
        print(l)
        print("\t", labels[l])
# Out:
# http://vivo.brown.edu/individual/n52190
# 	 {'Arthritis and rheumatism'}
# http://vivo.brown.edu/individual/n12312
# 	 {'Journal of Vision'}
# http://vivo.brown.edu/individual/n38511
# 	 {'J. Appl. Phys.'}
# http://vivo.brown.edu/individual/n79283
# 	 {'Brachytherapy'}
# http://vivo.brown.edu/individual/n79541
# 	 {'Science'}
# http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32
# 	 {"Alzheimer's & Dementia"}
# http://vivo.brown.edu/individual/n59735
# 	 {'Paediatric and perinatal epidemiology'}
# http://vivo.brown.edu/individual/n3917
# 	 {'Computer Methods in Applied Mechanics and Engineering'}
# http://vivo.brown.edu/individual/n91166
# 	 {'Journal of Computational Physics'}
# http://vivo.brown.edu/individual/n67856
# 	 {'Human Genetics'}
# http://vivo.brown.edu/individual/n28550
# 	 {'Neuropsychologia'}
# http://vivo.brown.edu/individual/n2053
# 	 {'Nanoscale'}
# http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee
# 	 {'Speculum'}
# http://vivo.brown.edu/individual/n27567
# 	 {'SIAM Journal on Mathematical Analysis'}
# http://vivo.brown.edu/individual/n1814
# 	 {'Violence'}
# http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c
# 	 {'Philosophical Topics'}
# http://vivo.brown.edu/individual/n52039
# 	 {'Mathematische Annalen'}
# http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905
# 	 {'International Journal of Heat and Mass Transfer'}
# http://vivo.brown.edu/individual/n17527
# 	 {'Head &amp; neck'}

# %%
tree = ET.parse('data/cleanup/describe_cites.rdf')
root = tree.getroot()
ns = root.nsmap
qn = { 'rdf' : '{{{0}}}'.format(ns['rdf']), 'bcite' : '{{{0}}}'.format(ns['bcite']),
     'rdfs' : '{{{0}}}'.format(ns['rdfs']), 'vitro' : '{{{0}}}'.format(ns['vitro'])}

# %%
add_node = ET.Element(qn['rdf'] + "RDF", nsmap=ns)
rmv_node = ET.Element(qn['rdf'] + "RDF", nsmap=ns)

skip_tags = { qn['bcite']+'venueFor', qn['bcite']+'issn', qn['bcite']+'eissn',
            qn['vitro']+'mostSpecificType' }
venue_titles = { 'The 2005 IEEE Annual Conference Wireless and Micrwave Technology, 2005.',
               'The Johns Hopkins medical journal', 'Chemico-biological interactions',
               'Advances in prostaglandin, thromboxane, and leukotriene research',
               'Earth Moon Planet', 'Biocomputing 2012'}
skip_rsc = { 'http://vivo.brown.edu/ontology/citation#Venue',
            'http://www.w3.org/2002/07/owl#Thing'}

nodes = root.findall('rdf:Description', ns)
for n in nodes:
    anode = ET.SubElement(add_node, qn['rdf'] + "Description")
    rnode = ET.SubElement(rmv_node, qn['rdf'] + "Description")
    rnode.set(qn['rdf']+'about', n.get(qn['rdf']+'about'))
    type_node = None
    noid_node = None
    spec_type = 'http://vivo.brown.edu/ontology/citation#Citation'
    for child in n:
        if child.tag not in skip_tags:
            rsc = child.get(qn['rdf']+'resource')
            if (rsc in skip_rsc or child.text in venue_titles):
                continue
            if (child.tag == qn['rdf'] + 'type'):
                if rsc == 'http://vivo.brown.edu/ontology/citation#NoID':
                    noid_node = deepcopy(child)
                    continue
                if spec_type == 'http://vivo.brown.edu/ontology/citation#Citation':
                    spec_type = child.get(qn['rdf']+'resource')
                    type_node = deepcopy(child)
                continue
            anode.append(deepcopy(child))
            rnode.append(deepcopy(child))
    anode.append(deepcopy(type_node))
    rnode.append(deepcopy(type_node))
    if noid_node is not None:
        rnode.append(noid_node)

# %%
for e, a in enumerate(add_node):
    print("{}: {} of {}".format(e, a.tag, a.get(qn['rdf'] + 'about')))
    for c in a:
        print('\t', c.tag, c.attrib, c.text)
    print('-'*100)
print('\n\n'+ '='*100 + '\n\n')
for e, a in enumerate(rmv_node):
    print("{}: {} of {}".format(e, a.tag, a.get(qn['rdf'] + 'about')))
    for c in a:
        print('\t', c.tag, c.attrib, c.text)
    print('-'*100)
# Out:
# 0: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 411
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 36
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Dickson, James L., Head, James W., Marchant, David R.
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1130/g24382a.1
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n38102'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Science
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 5
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jheadiii'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2008-01-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 1: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2007-12-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n71549'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dkielmd'} None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 6
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Calcium intake and hip fracture risk in men and women: a meta-analysis of prospective cohort studies and randomized controlled trials.
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Bischoff-Ferrari HA, Dawson-Hughes B, Baron JA, Burckhardt P, Li R, Spiegelman D, Specker B, Orav JE, Wong JB, Staehelin HB, O'Reilly E, Kiel DP, Willett WC
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 86
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 18065599
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1780-90
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 2: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 6
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/bsandste'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1866-1898
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 247
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} SIAM Journal on Mathematical Analysis
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-09-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n59796'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1016/j.jde.2009.06.010
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Manukian, Vahagn, Sandstede, Björn
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 3: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 92
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/mbossy'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 795-796
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Speculum
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee'} None
# 	 {http://vivo.brown.edu/ontology/citation#}url {} http://www.journals.uchicago.edu/doi/full/10.1086/692251
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2017-01-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Review'} None
# ----------------------------------------------------------------------------------------------------
# 4: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 328-328
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Journal of Vision
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 1
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1167/1.3.328
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n12312'} None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Chen, J. T., Domini, F., Caudek, C.
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/fdomini'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2001-12-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 5: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2010-09-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/eupfal'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.14778/1920841.1921000
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/naa47f3a9778247f3b6331331109e7c3f'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Database-support for continuous prediction queries over streaming data
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 1-2
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Akdere, Mert, Çetintemel, Uǧur, Upfal, Eli
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1291-1301
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 6: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Harville EW, Savitz DA, Dole N, Herring AH, Thorp JM
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1089/jwh.2008.1102
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-09-01
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Arthritis and rheumatism
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dsavitz'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC2825685
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 9
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1425-33
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/nebf5c5783c714f37900b9874f2535c8d'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 19757520
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 18
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 7: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.4064/aa137-3-8
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/johsilve'} None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Silverman, Joseph H., Voloch, José Felipe
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-01-01
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 137
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 285-294
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Mathematische Annalen
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n85397'} None
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 8: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 14
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1765-70
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Kim DH, Nelson HH, Wiencke JK, Christiani DC, Wain JC, Mark EJ, Kelsey KT
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Human Genetics
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n73662'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 11313923
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 20
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ktkelsey'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1038/sj.onc.1204302
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2001-03-29
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 9: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 2
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 939-965
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Journal of Computational Physics
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n66392'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 33
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Liu, Yuanyuan, Shu, Chi-Wang, Zhang, Mengping
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1137/100791002
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/cshu'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2011-01-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 10: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 14
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n12199'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2014-07-01
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Recent Ice Ages on Mars: The role of radiatively active clouds and cloud microphysics
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Madeleine, J.-B., Head, J. W., Forget, F., Navarro, T., Millour, E., Spiga, A., Colaïtis, A., Määttänen, A., Montmessin, F., Dickson, J. L.
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 41
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jheadiii'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 4873-4879
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1002/2014gl059861
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 11: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 14
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 20297818
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Kim, Jaemin, Lee, Youngmin, Sun, Shouheng
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n22502'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} J. Appl. Phys.
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1021/ja1009629
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2010-04-01
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 4996-4997
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ssun'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 132
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 12: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Dong, Suchuan, Karniadakis, George Em
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1016/j.parco.2003.05.020
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 1
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2004-01-01
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Computer Methods in Applied Mechanics and Engineering
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1-20
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 30
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n38254'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/gkarniad'} None
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 13: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 20696650
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1093/aje/kwq181
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 7
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dsavitz'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Paediatric and perinatal epidemiology
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Kheifets L, Ahlbom A, Crespi CM, Feychting M, Johansen C, Monroe J, Murphy MF, Oksuzyan S, Preston-Martin S, Roman E, Saito T, Savitz D, Schüz J, Simpson J, Swanson J, Tynes T, Verkasalo P, Mezei G
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 752-61
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC2984256
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n68890'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 172
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2010-10-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 14: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n94622'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dwazermd'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Brachytherapy
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Hiatt J, Cardarelli G, Hepel J, Wazer D, Sternick E
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1120/jacmp.v9i3.2775
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2008-06-23
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 2775
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 18716592
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 9
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 15: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Nanoscale
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 13
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 23426846
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ssun'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1002/anie.201300276
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 52
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2013-02-01
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Zhang, Sen, Metin, Önder, Su, Dong, Sun, Shouheng
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n17650'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 3681-3684
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 16: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1016/j.humov.2006.05.001
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/wwarrenj'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Philosophical Topics
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Fernandez, Laure, Warren, William H., Bootsma, Reinoud J.
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n94296'} None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 6
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 695-717
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2006-12-01
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 16859793
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 25
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 17: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n61347'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jwandsmd'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 9462667
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Melegari M, Scaglioni PP, Wands JR
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 628-33
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 2
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 1998-02-01
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1002/hep.510270243
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Hepatitis B virus mutants associated with 3TC and famciclovir administration are replication defective.
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 27
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 18: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Koga, Hironori, Kim, Miran, Tomimaru, Yoshito, Nakamura, Toru, Abe, Mitsuhiko, Hashimoto, Osamu, Ikezono, Yu, Masuda, Hiroshi, Yano, Hirohisa, Ueno, Takato, Torimura, Takuji, Wands, Jack R., Sata, Michio
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jwandsmd'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 73
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 8 Supplement
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Alzheimer's & Dementia
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n90939'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 890-890
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1158/1538-7445.am2013-890
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2013-04-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 19: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Head &amp; neck
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n58380'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 76
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2000-07-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ktkelsey'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 955-61
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 10923619
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 7
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Platz EA, Wiencke JK, Kelsey KT, Janower ML, Schottenfeld D, Travis LB, Goldman MB
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 20: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 200-207
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Brayboy, L.M., Wessel, G.M.
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC4767051
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} International Journal of Heat and Mass Transfer
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/gwessel'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1093/molehr/gav064
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 22
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n42716'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2015-11-01
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 26590170
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 21: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC2722143
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 30
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 78-87
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 1
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Chang JS, Wrensch MR, Hansen HM, Sison JD, Aldrich MC, Quesenberry CP Jr, Seldin MF, Kelsey KT, Wiencke JK
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 19029194
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-01-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ktkelsey'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1093/carcin/bgn261
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n29509'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Base excision repair genes and risk of lung cancer among San Francisco Bay Area Latinos and African-Americans.
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 22: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 903-912
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 28874943
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.5811/westjem.2017.6.34849
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 18
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 5
# 	 {http://vivo.brown.edu/ontology/citation#}publishedIn {} Western Journal of Emergency Medicine
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/mranney'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Violence
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Knoepke, Christopher, Allen, Amanda, Ranney, Megan, Wintemute, Garen, Matlock, Daniel, Betz, Marian
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC5576627
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2017-08-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n76419'} None
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Citation'} None
# ----------------------------------------------------------------------------------------------------
# 23: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.2337/dc11-1687
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 22301123
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n90749'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Neuropsychologia
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC3322718
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 35
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 574-80
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dcoustan'} None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Lowe LP, Metzger BE, Dyer AR, Lowe J, McCance DR, Lappin TR, Trimble ER, Coustan DR, Hadden DR, Hod M, Oats JJ, Persson B, HAPO Study Cooperative Research Group
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2012-03-01
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 24: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 321-333
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Larson, Lawrence
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ll7'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n50404'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 102
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} RF and Microwave Hardware Challenges for Future Radio Spectrum Access
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2014-03-01
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1109/jproc.2014.2298231
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
#
#
# ====================================================================================================
#
#
# 0: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n79541
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 411
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 36
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Dickson, James L., Head, James W., Marchant, David R.
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1130/g24382a.1
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n38102'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Science
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 5
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jheadiii'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2008-01-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 1: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n57636
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2007-12-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n71549'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dkielmd'} None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 6
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Calcium intake and hip fracture risk in men and women: a meta-analysis of prospective cohort studies and randomized controlled trials.
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Bischoff-Ferrari HA, Dawson-Hughes B, Baron JA, Burckhardt P, Li R, Spiegelman D, Specker B, Orav JE, Wong JB, Staehelin HB, O'Reilly E, Kiel DP, Willett WC
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 86
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 18065599
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1780-90
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 2: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n27567
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 6
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/bsandste'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1866-1898
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 247
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} SIAM Journal on Mathematical Analysis
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-09-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n59796'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1016/j.jde.2009.06.010
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Manukian, Vahagn, Sandstede, Björn
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 3: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 92
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/mbossy'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 795-796
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Speculum
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee'} None
# 	 {http://vivo.brown.edu/ontology/citation#}url {} http://www.journals.uchicago.edu/doi/full/10.1086/692251
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2017-01-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Review'} None
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#NoID'} None
# ----------------------------------------------------------------------------------------------------
# 4: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n12312
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 328-328
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Journal of Vision
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 1
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1167/1.3.328
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n12312'} None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Chen, J. T., Domini, F., Caudek, C.
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/fdomini'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2001-12-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 5: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n32612
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2010-09-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/eupfal'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.14778/1920841.1921000
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/naa47f3a9778247f3b6331331109e7c3f'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Database-support for continuous prediction queries over streaming data
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 1-2
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Akdere, Mert, Çetintemel, Uǧur, Upfal, Eli
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1291-1301
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 6: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n52190
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Harville EW, Savitz DA, Dole N, Herring AH, Thorp JM
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1089/jwh.2008.1102
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-09-01
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Arthritis and rheumatism
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dsavitz'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC2825685
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 9
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1425-33
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/nebf5c5783c714f37900b9874f2535c8d'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 19757520
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 18
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 7: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n52039
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.4064/aa137-3-8
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/johsilve'} None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Silverman, Joseph H., Voloch, José Felipe
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-01-01
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 137
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 285-294
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Mathematische Annalen
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n85397'} None
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 8: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n67856
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 14
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 1765-70
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Kim DH, Nelson HH, Wiencke JK, Christiani DC, Wain JC, Mark EJ, Kelsey KT
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Human Genetics
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n73662'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 11313923
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 20
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ktkelsey'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1038/sj.onc.1204302
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2001-03-29
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 9: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n91166
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 2
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 939-965
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Journal of Computational Physics
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n66392'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 33
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Liu, Yuanyuan, Shu, Chi-Wang, Zhang, Mengping
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1137/100791002
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/cshu'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2011-01-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 10: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n44730
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 14
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n12199'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2014-07-01
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Recent Ice Ages on Mars: The role of radiatively active clouds and cloud microphysics
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Madeleine, J.-B., Head, J. W., Forget, F., Navarro, T., Millour, E., Spiga, A., Colaïtis, A., Määttänen, A., Montmessin, F., Dickson, J. L.
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 41
# ...
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2010-10-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 14: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n79283
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n94622'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dwazermd'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Brachytherapy
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Hiatt J, Cardarelli G, Hepel J, Wazer D, Sternick E
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1120/jacmp.v9i3.2775
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2008-06-23
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 2775
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 18716592
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 9
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 15: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n2053
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Nanoscale
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 13
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 23426846
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ssun'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1002/anie.201300276
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 52
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2013-02-01
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Zhang, Sen, Metin, Önder, Su, Dong, Sun, Shouheng
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n17650'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 3681-3684
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 16: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1016/j.humov.2006.05.001
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/wwarrenj'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Philosophical Topics
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Fernandez, Laure, Warren, William H., Bootsma, Reinoud J.
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n94296'} None
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 6
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 695-717
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2006-12-01
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 16859793
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 25
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 17: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n21627
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n61347'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jwandsmd'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 9462667
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Melegari M, Scaglioni PP, Wands JR
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 628-33
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 2
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 1998-02-01
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1002/hep.510270243
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Hepatitis B virus mutants associated with 3TC and famciclovir administration are replication defective.
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 27
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 18: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Koga, Hironori, Kim, Miran, Tomimaru, Yoshito, Nakamura, Toru, Abe, Mitsuhiko, Hashimoto, Osamu, Ikezono, Yu, Masuda, Hiroshi, Yano, Hirohisa, Ueno, Takato, Torimura, Takuji, Wands, Jack R., Sata, Michio
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/jwandsmd'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 73
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 8 Supplement
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Alzheimer's & Dementia
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n90939'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 890-890
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1158/1538-7445.am2013-890
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2013-04-01
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 19: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n17527
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Head &amp; neck
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n58380'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 76
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2000-07-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ktkelsey'} None
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 955-61
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 10923619
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 7
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Platz EA, Wiencke JK, Kelsey KT, Janower ML, Schottenfeld D, Travis LB, Goldman MB
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 20: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 200-207
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Brayboy, L.M., Wessel, G.M.
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC4767051
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} International Journal of Heat and Mass Transfer
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/gwessel'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1093/molehr/gav064
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 22
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n42716'} None
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2015-11-01
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 26590170
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 21: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n16928
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC2722143
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 30
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 78-87
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 1
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Chang JS, Wrensch MR, Hansen HM, Sison JD, Aldrich MC, Quesenberry CP Jr, Seldin MF, Kelsey KT, Wiencke JK
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 19029194
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2009-01-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ktkelsey'} None
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1093/carcin/bgn261
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n29509'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Base excision repair genes and risk of lung cancer among San Francisco Bay Area Latinos and African-Americans.
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 22: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n1814
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 903-912
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 28874943
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.5811/westjem.2017.6.34849
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 18
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 5
# 	 {http://vivo.brown.edu/ontology/citation#}publishedIn {} Western Journal of Emergency Medicine
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/mranney'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Violence
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Knoepke, Christopher, Allen, Amanda, Ranney, Megan, Wintemute, Garen, Matlock, Daniel, Betz, Marian
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC5576627
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2017-08-01
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n76419'} None
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Citation'} None
# ----------------------------------------------------------------------------------------------------
# 23: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n28550
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.2337/dc11-1687
# 	 {http://vivo.brown.edu/ontology/citation#}pmid {} 22301123
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n90749'} None
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} Neuropsychologia
# 	 {http://vivo.brown.edu/ontology/citation#}pmcid {} PMC3322718
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 35
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 574-80
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/dcoustan'} None
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Lowe LP, Metzger BE, Dyer AR, Lowe J, McCance DR, Lappin TR, Trimble ER, Coustan DR, Hadden DR, Hod M, Oats JJ, Persson B, HAPO Study Cooperative Research Group
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2012-03-01
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------
# 24: {http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description of http://vivo.brown.edu/individual/n5101
# 	 {http://vivo.brown.edu/ontology/citation#}issue {} 3
# 	 {http://vivo.brown.edu/ontology/citation#}pages {} 321-333
# 	 {http://vivo.brown.edu/ontology/citation#}authorList {} Larson, Lawrence
# 	 {http://vivo.brown.edu/ontology/citation#}hasContributor {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/ll7'} None
# 	 {http://vivo.brown.edu/ontology/citation#}hasVenue {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/individual/n50404'} None
# 	 {http://vivo.brown.edu/ontology/citation#}volume {} 102
# 	 {http://www.w3.org/2000/01/rdf-schema#}label {} RF and Microwave Hardware Challenges for Future Radio Spectrum Access
# 	 {http://vivo.brown.edu/ontology/citation#}date {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}datatype': 'http://www.w3.org/2001/XMLSchema#date'} 2014-03-01
# 	 {http://vivo.brown.edu/ontology/citation#}doi {} 10.1109/jproc.2014.2298231
# 	 {http://www.w3.org/1999/02/22-rdf-syntax-ns#}type {'{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource': 'http://vivo.brown.edu/ontology/citation#Article'} None
# ----------------------------------------------------------------------------------------------------

# %%
contribs = collections.defaultdict(set)
for r in rows:
    if r[1] == 'http://vivo.brown.edu/ontology/citation#hasContributor':
        contribs[r[2][33:]].add(r[0])
contribs
# Out:
# defaultdict(set,
#             {'dsavitz': {'http://vivo.brown.edu/individual/n52190',
#               'http://vivo.brown.edu/individual/n59735'},
#              'fdomini': {'http://vivo.brown.edu/individual/n12312'},
#              'ssun': {'http://vivo.brown.edu/individual/n2053',
#               'http://vivo.brown.edu/individual/n38511'},
#              'dwazermd': {'http://vivo.brown.edu/individual/n79283'},
#              'jheadiii': {'http://vivo.brown.edu/individual/n44730',
#               'http://vivo.brown.edu/individual/n79541'},
#              'jwandsmd': {'http://vivo.brown.edu/individual/n21627',
#               'http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32'},
#              'll7': {'http://vivo.brown.edu/individual/n5101'},
#              'gkarniad': {'http://vivo.brown.edu/individual/n3917'},
#              'cshu': {'http://vivo.brown.edu/individual/n91166'},
#              'ktkelsey': {'http://vivo.brown.edu/individual/n16928',
#               'http://vivo.brown.edu/individual/n17527',
#               'http://vivo.brown.edu/individual/n67856'},
#              'dcoustan': {'http://vivo.brown.edu/individual/n28550'},
#              'mbossy': {'http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee'},
#              'bsandste': {'http://vivo.brown.edu/individual/n27567'},
#              'mranney': {'http://vivo.brown.edu/individual/n1814'},
#              'wwarrenj': {'http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c'},
#              'dkielmd': {'http://vivo.brown.edu/individual/n57636'},
#              'johsilve': {'http://vivo.brown.edu/individual/n52039'},
#              'gwessel': {'http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905'},
#              'eupfal': {'http://vivo.brown.edu/individual/n32612'}})

# %%
pkeys = []
for c, sids in contribs.items():
    for s in sids:
        tmpl = { 'short_id': c, 'rabid': s, 'doi':'', 'pmid': '', 'url': ''}
        for k,v in crabids[s].items():
            if k in tmpl:
                tmpl[k] = v
        pkeys.append(tmpl)
pkeys
# Out:
# [{'short_id': 'dsavitz',
#   'rabid': 'http://vivo.brown.edu/individual/n59735',
#   'doi': '10.1093/aje/kwq181',
#   'pmid': '20696650',
#   'url': ''},
#  {'short_id': 'dsavitz',
#   'rabid': 'http://vivo.brown.edu/individual/n52190',
#   'doi': '10.1089/jwh.2008.1102',
#   'pmid': '19757520',
#   'url': ''},
#  {'short_id': 'fdomini',
#   'rabid': 'http://vivo.brown.edu/individual/n12312',
#   'doi': '10.1167/1.3.328',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'ssun',
#   'rabid': 'http://vivo.brown.edu/individual/n38511',
#   'doi': '10.1021/ja1009629',
#   'pmid': '20297818',
#   'url': ''},
#  {'short_id': 'ssun',
#   'rabid': 'http://vivo.brown.edu/individual/n2053',
#   'doi': '10.1002/anie.201300276',
#   'pmid': '23426846',
#   'url': ''},
#  {'short_id': 'dwazermd',
#   'rabid': 'http://vivo.brown.edu/individual/n79283',
#   'doi': '10.1120/jacmp.v9i3.2775',
#   'pmid': '18716592',
#   'url': ''},
#  {'short_id': 'jheadiii',
#   'rabid': 'http://vivo.brown.edu/individual/n44730',
#   'doi': '10.1002/2014gl059861',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'jheadiii',
#   'rabid': 'http://vivo.brown.edu/individual/n79541',
#   'doi': '10.1130/g24382a.1',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'jwandsmd',
#   'rabid': 'http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32',
#   'doi': '10.1158/1538-7445.am2013-890',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'jwandsmd',
#   'rabid': 'http://vivo.brown.edu/individual/n21627',
#   'doi': '10.1002/hep.510270243',
#   'pmid': '9462667',
#   'url': ''},
#  {'short_id': 'll7',
#   'rabid': 'http://vivo.brown.edu/individual/n5101',
#   'doi': '10.1109/jproc.2014.2298231',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'gkarniad',
#   'rabid': 'http://vivo.brown.edu/individual/n3917',
#   'doi': '10.1016/j.parco.2003.05.020',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'cshu',
#   'rabid': 'http://vivo.brown.edu/individual/n91166',
#   'doi': '10.1137/100791002',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'ktkelsey',
#   'rabid': 'http://vivo.brown.edu/individual/n67856',
#   'doi': '10.1038/sj.onc.1204302',
#   'pmid': '11313923',
#   'url': ''},
#  {'short_id': 'ktkelsey',
#   'rabid': 'http://vivo.brown.edu/individual/n17527',
#   'doi': '',
#   'pmid': '10923619',
#   'url': ''},
#  {'short_id': 'ktkelsey',
#   'rabid': 'http://vivo.brown.edu/individual/n16928',
#   'doi': '10.1093/carcin/bgn261',
#   'pmid': '19029194',
#   'url': ''},
#  {'short_id': 'dcoustan',
#   'rabid': 'http://vivo.brown.edu/individual/n28550',
#   'doi': '10.2337/dc11-1687',
#   'pmid': '22301123',
#   'url': ''},
#  {'short_id': 'mbossy',
#   'rabid': 'http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee',
#   'doi': '',
#   'pmid': '',
#   'url': 'http://www.journals.uchicago.edu/doi/full/10.1086/692251'},
#  {'short_id': 'bsandste',
#   'rabid': 'http://vivo.brown.edu/individual/n27567',
#   'doi': '10.1016/j.jde.2009.06.010',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'mranney',
#   'rabid': 'http://vivo.brown.edu/individual/n1814',
#   'doi': '10.5811/westjem.2017.6.34849',
#   'pmid': '28874943',
#   'url': ''},
#  {'short_id': 'wwarrenj',
#   'rabid': 'http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c',
#   'doi': '10.1016/j.humov.2006.05.001',
#   'pmid': '16859793',
#   'url': ''},
#  {'short_id': 'dkielmd',
#   'rabid': 'http://vivo.brown.edu/individual/n57636',
#   'doi': '',
#   'pmid': '18065599',
#   'url': ''},
#  {'short_id': 'johsilve',
#   'rabid': 'http://vivo.brown.edu/individual/n52039',
#   'doi': '10.4064/aa137-3-8',
#   'pmid': '',
#   'url': ''},
#  {'short_id': 'gwessel',
#   'rabid': 'http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905',
#   'doi': '10.1093/molehr/gav064',
#   'pmid': '26590170',
#   'url': ''},
#  {'short_id': 'eupfal',
#   'rabid': 'http://vivo.brown.edu/individual/n32612',
#   'doi': '10.14778/1920841.1921000',
#   'pmid': '',
#   'url': ''}]

# %%
dois = { p['doi']: p for p in pkeys if p['doi'] != ''}
pmids = { p['pmid']: p for p in pkeys if p['pmid'] != ''}
print("DOIs: ",len(dois))
print("PMIDs: ",len(pmids))
# Out:
# DOIs:  22
# PMIDs:  14

# %%
doi_match = {}
pmid_match = {}
matched = set()
for v in vmgr:
    if v['doi'] in dois:
        doi_match[v['doi']] = v
        matched.add(frozenset(dois[v['doi']].values()))
    if v['pmid'].lower() in pmids:
        pmid_match[v['pmid']] = v['pmid']
        matched.add(frozenset(pmids[v['pmid']].values()))

# %%
len(matched)
# Out:
# 24

# %%
matched
# Out:
# {frozenset({'',
#             '10.1002/hep.510270243',
#             '9462667',
#             'http://vivo.brown.edu/individual/n21627',
#             'jwandsmd'}),
#  frozenset({'',
#             '10.1038/sj.onc.1204302',
#             '11313923',
#             'http://vivo.brown.edu/individual/n67856',
#             'ktkelsey'}),
#  frozenset({'',
#             '10.1109/jproc.2014.2298231',
#             'http://vivo.brown.edu/individual/n5101',
#             'll7'}),
#  frozenset({'',
#             '10.1016/j.jde.2009.06.010',
#             'bsandste',
#             'http://vivo.brown.edu/individual/n27567'}),
#  frozenset({'',
#             '10.1093/carcin/bgn261',
#             '19029194',
#             'http://vivo.brown.edu/individual/n16928',
#             'ktkelsey'}),
#  frozenset({'',
#             '10.1002/2014gl059861',
#             'http://vivo.brown.edu/individual/n44730',
#             'jheadiii'}),
#  frozenset({'',
#             '10.2337/dc11-1687',
#             '22301123',
#             'dcoustan',
#             'http://vivo.brown.edu/individual/n28550'}),
#  frozenset({'',
#             '10.1158/1538-7445.am2013-890',
#             'http://vivo.brown.edu/individual/n855be37b19f14d619c2adf820ae33f32',
#             'jwandsmd'}),
#  frozenset({'',
#             '10.1120/jacmp.v9i3.2775',
#             '18716592',
#             'dwazermd',
#             'http://vivo.brown.edu/individual/n79283'}),
#  frozenset({'',
#             '10.1016/j.humov.2006.05.001',
#             '16859793',
#             'http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c',
#             'wwarrenj'}),
#  frozenset({'',
#             '10.1089/jwh.2008.1102',
#             '19757520',
#             'dsavitz',
#             'http://vivo.brown.edu/individual/n52190'}),
#  frozenset({'',
#             '10.4064/aa137-3-8',
#             'http://vivo.brown.edu/individual/n52039',
#             'johsilve'}),
#  frozenset({'',
#             '10.1137/100791002',
#             'cshu',
#             'http://vivo.brown.edu/individual/n91166'}),
#  frozenset({'',
#             '10.1016/j.parco.2003.05.020',
#             'gkarniad',
#             'http://vivo.brown.edu/individual/n3917'}),
#  frozenset({'',
#             '10.1130/g24382a.1',
#             'http://vivo.brown.edu/individual/n79541',
#             'jheadiii'}),
#  frozenset({'',
#             '10.14778/1920841.1921000',
#             'eupfal',
#             'http://vivo.brown.edu/individual/n32612'}),
#  frozenset({'',
#             '10.1093/aje/kwq181',
#             '20696650',
#             'dsavitz',
#             'http://vivo.brown.edu/individual/n59735'}),
#  frozenset({'',
#             '10.1021/ja1009629',
#             '20297818',
#             'http://vivo.brown.edu/individual/n38511',
#             'ssun'}),
#  frozenset({'',
#             '10.1002/anie.201300276',
#             '23426846',
#             'http://vivo.brown.edu/individual/n2053',
#             'ssun'}),
#  frozenset({'',
#             '18065599',
#             'dkielmd',
#             'http://vivo.brown.edu/individual/n57636'}),
#  frozenset({'',
#             '10923619',
#             'http://vivo.brown.edu/individual/n17527',
#             'ktkelsey'}),
#  frozenset({'',
#             '10.5811/westjem.2017.6.34849',
#             '28874943',
#             'http://vivo.brown.edu/individual/n1814',
#             'mranney'}),
#  frozenset({'',
#             '10.1167/1.3.328',
#             'fdomini',
#             'http://vivo.brown.edu/individual/n12312'}),
#  frozenset({'',
#             '10.1093/molehr/gav064',
#             '26590170',
#             'gwessel',
#             'http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905'})}

# %%
for d in dois:
    if d not in doi_match:
        print(dois[d])
# Out:
# {'short_id': 'dsavitz', 'rabid': 'http://vivo.brown.edu/individual/n52190', 'doi': '10.1089/jwh.2008.1102', 'pmid': '19757520', 'url': ''}
# {'short_id': 'dwazermd', 'rabid': 'http://vivo.brown.edu/individual/n79283', 'doi': '10.1120/jacmp.v9i3.2775', 'pmid': '18716592', 'url': ''}

# %%
for d in pmids:
    if d not in pmid_match:
        print(pmids[d])
# Out:
# {'short_id': 'ssun', 'rabid': 'http://vivo.brown.edu/individual/n38511', 'doi': '10.1021/ja1009629', 'pmid': '20297818', 'url': ''}
# {'short_id': 'ssun', 'rabid': 'http://vivo.brown.edu/individual/n2053', 'doi': '10.1002/anie.201300276', 'pmid': '23426846', 'url': ''}
# {'short_id': 'mranney', 'rabid': 'http://vivo.brown.edu/individual/n1814', 'doi': '10.5811/westjem.2017.6.34849', 'pmid': '28874943', 'url': ''}
# {'short_id': 'wwarrenj', 'rabid': 'http://vivo.brown.edu/individual/n7b205dc5b041431da1f101ae2c08499c', 'doi': '10.1016/j.humov.2006.05.001', 'pmid': '16859793', 'url': ''}
# {'short_id': 'gwessel', 'rabid': 'http://vivo.brown.edu/individual/nd6e87771a19c4065bfc50964259ed905', 'doi': '10.1093/molehr/gav064', 'pmid': '26590170', 'url': ''}

# %%
len(doi_match)
# Out:
# 20

# %%
len(pmid_match)
# Out:
# 9

# %%
c = 1
for p in pkeys:
    if p['doi'] in doi_match:
        print(c)
        print(json.loads(doi_match[p['doi']]['display'])['citation']['uri'])
        c+=1
# Out:
# 1
# http://vivo.brown.edu/individual/n89483
# 2
# http://vivo.brown.edu/individual/n415
# 3
# http://vivo.brown.edu/individual/n81532
# 4
# http://vivo.brown.edu/individual/n48063
# 5
# http://vivo.brown.edu/individual/n44730
# 6
# http://vivo.brown.edu/individual/n87370
# 7
# http://vivo.brown.edu/individual/n64700
# 8
# http://vivo.brown.edu/individual/n21627
# 9
# http://vivo.brown.edu/individual/n5101
# 10
# http://vivo.brown.edu/individual/n68447
# 11
# http://vivo.brown.edu/individual/n98010
# 12
# http://vivo.brown.edu/individual/n5868
# 13
# http://vivo.brown.edu/individual/n16928
# 14
# http://vivo.brown.edu/individual/n28054
# 15
# http://vivo.brown.edu/individual/n8655
# 16
# http://vivo.brown.edu/individual/n17882
# 17
# http://vivo.brown.edu/individual/n10978
# 18
# http://vivo.brown.edu/individual/n32902
# 19
# http://vivo.brown.edu/individual/n79206
# 20
# http://vivo.brown.edu/individual/n32612

# %%
'10.1002/ANIE.201300276'.lower()
# Out:
# '10.1002/anie.201300276'

# %%
def get_node_data(node):
    return (node.tag, node.get('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}resource') or node.text)

# %%
def get_node_uri(node):
    return node.get('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about')

# %%
def filter_node(node, matches, on_property=False):
    if on_property:
        return get_node_data(node)[0] in matches
    else:
        return get_node_data(node) in matches

# %%
def filter_citation_titles(node):
    extra_titles = {'RF and Microwave Hardware Challenges for Future Radio Spectrum Access',
                    'Hepatitis B virus mutants associated with 3TC and famciclovir administration are replication defective.'
                    'Base excision repair genes and risk of lung cancer among San Francisco Bay Area Latinos and African-Americans.',
                    'Calcium intake and hip fracture risk in men and women: a meta-analysis of prospective cohort studies and randomized controlled trials.',
                    'Recent Ice Ages on Mars: The role of radiatively active clouds and cloud microphysics',
                    'Database-support for continuous prediction queries over streaming data' }
    bad_data = { ('{http://www.w3.org/2000/01/rdf-schema#}label', t) for t in extra_titles }
    return filter_node(node, bad_data)

# %%
def filter_venue_type(node):
    venue_data = { '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type','http://vivo.brown.edu/ontology/citation#Venue' }
    return not filter_node(node, venue_data)

# %%
def filter_venue_props(node):
    venue_props = { '{http://vivo.brown.edu/ontology/citation#}venueFor',
                   '{http://vivo.brown.edu/ontology/citation#}issn',
                   '{http://vivo.brown.edu/ontology/citation#}eissn' }
    return not filter_node(node, venue_props, on_property=True)

# %%
def is_citation_data(node):
    return filter_venue_props(node) and filter_venue_type(node)

# %%
def filter_inferred_data(node):
    inf_data = {
        ('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type','http://www.w3.org/2002/07/owl#Thing'),
        ('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type','http://vivo.brown.edu/ontology/citation#Citation')
    }
    return not filter_node(node, inf_data)

# %%
def filter_inferred_props(node):
    inf_props = { '{http://vitro.mannlib.cornell.edu/ns/vitro/0.7#}mostSpecificType' }
    return not filter_node(node, inf_props, on_property=True)

# %%
def is_asserted(node):
    return filter_inferred_data(node) and filter_inferred_props(node)

# %%
def get_sample_citation_type(nodes):
    for n in nodes:
        if get_node_data(n[1]) == ('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type','http://vivo.brown.edu/ontology/citation#Citation'):
            return deepcopy(n[1])

# %%
def add_assertion(nodes, samp):
    asserted = [ d for d in nodes if get_node_data(d)[0] == '{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type' ]
    if not asserted:
        nodes.add(deepcopy(samp))
    return nodes

# %%
def remove_assertion(nodes, test):
    return [ d for d in nodes if get_node_data(d) != test ]

# %%
def make_new_node(uri, elems):
    node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}Description')
    node.set('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}about', uri)
    for e in elems:
        node.append(deepcopy(e))
    return node

# %%
def duplicate_nodes(uri, elems):
    a = make_new_node('',
        remove_assertion(elems, ('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type','http://vivo.brown.edu/ontology/citation#NoID')))
    r = make_new_node(uri, elems)
    return (a, r)

# %%
def get_node_identifiers(node):
    ids = { 'doi': '', 'pmid': '', 'url':'' }
    props = {'{http://vivo.brown.edu/ontology/citation#}doi',
            '{http://vivo.brown.edu/ontology/citation#}pmid',
            '{http://vivo.brown.edu/ontology/citation#}url'}
    for n in node:
        p, o = get_node_data(n)
        if p in props:
            ids[ p[p.index('#')+2:] ] = o
    return ids

# %%
def filter_json(jdata):
    try:
        d = json.loads(jdata)
        return True
    except:
        return False

# %%
def get_pub_data(pub):
    jdata = json.loads(pub['display'])
    return (
        ( pub['doi'], pub['pmid'], jdata['url'] ),
        ( pub['short_id'], jdata['citation'].get('title'), jdata['citation'].get('uri') )
    )

# %%
def map_node_to_pub(nodeIds, node, doiDict, pmidDict, urlDict):
    if nodeIds['doi'] in doiDict:
        return (node, doiDict[nodeIds['doi']])
    if nodeIds['pmid'] in pmidDict:
        return (node, pmidDict[nodeIds['pmid']])
    if nodeIds['url'] in urlDict:
        return (node, urlDict[nodeIds['url']])
    return (node, False)

# %%
def check_author(node, data):
    nd = [ get_node_data(n) for n in node ]
    auths = [ n[1] for n in nd if n[0] == '{http://vivo.brown.edu/ontology/citation#}hasContributor']
    return data[0] in auths

# %%
with open('data/cleanup/pubs.tsv') as f:
    rdr = csv.DictReader(f, delimiter='\t')
    vmgr = [ r for r in rdr ]

for v in vmgr:
    v['doi'] = v['doi'].lower()

# %%
tree = ET.parse('data/cleanup/describe_cites.rdf')
root = tree.getroot()
ns = root.nsmap

# %%
nodes = root.findall('rdf:Description', ns)
cite_data = [ (get_node_uri(n), d) for n in nodes for d in n if is_citation_data(d) ]
cite_data = [ (get_node_uri(n), d) for n in nodes for d in n if is_citation_data(d) ]
asserted_data = [ (uri, d) for uri, d in cite_data if is_asserted(d) ]

fused = collections.defaultdict(set)
for data in asserted_data:
    fused[data[0]].add(data[1])
sample_cite = get_sample_citation_type(cite_data)
fully_typed = [ (uri, add_assertion(fused[uri], sample_cite)) for uri in fused ]
split_nodes = [ duplicate_nodes(uri, assrts) for uri, assrts in fully_typed ]

to_remove = [ n[1] for n in split_nodes ]
wrapped_nodes = [ (get_node_identifiers(n[0]), n[0]) for n in split_nodes ]

good_pubs = [ p for p in vmgr if filter_json(p['display']) ]
wrapped_pubs = [ get_pub_data(pub) for pub in good_pubs ]
doi_pubs = { d[0][0]: d[1] for d in wrapped_pubs }
pmid_pubs = { d[0][1]: d[1] for d in wrapped_pubs }
url_pubs = { d[0][2]: d[1] for d in wrapped_pubs }

mapped = [ map_node_to_pub(node_ids, node, doi_pubs, pmid_pubs, url_pubs)
          for node_ids, node in wrapped_nodes ]
for m in mapped:
    if not m[1]:
        for n in m[0]:
            print(get_node_data(n))
checked = [ check_author(node[0], node[1]) for node in mapped ]
# add_node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}RDF', nsmap=ns)
# rmv_node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}RDF', nsmap=ns)
# add_rmv = [ make_ for ]
# Out:
# ('{http://vivo.brown.edu/ontology/citation#}hasContributor', 'http://vivo.brown.edu/individual/mbossy')
# ('{http://vivo.brown.edu/ontology/citation#}url', 'http://www.journals.uchicago.edu/doi/full/10.1086/692251')
# ('{http://vivo.brown.edu/ontology/citation#}pages', '795-796')
# ('{http://vivo.brown.edu/ontology/citation#}issue', '3')
# ('{http://vivo.brown.edu/ontology/citation#}date', '2017-01-01')
# ('{http://www.w3.org/2000/01/rdf-schema#}label', 'Speculum')
# ('{http://vivo.brown.edu/ontology/citation#}hasVenue', 'http://vivo.brown.edu/individual/n8081cd271207487a9ab47e57c0a2caee')
# ('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}type', 'http://vivo.brown.edu/ontology/citation#Review')
# ('{http://vivo.brown.edu/ontology/citation#}volume', '92')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-232-526ca6039201> in <module>
#      25         for n in m[0]:
#      26             print(get_node_data(n))
# ---> 27 checked = [ check_author(node[0], node[1]) for node in mapped ]
#      28 # add_node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}RDF', nsmap=ns)
#      29 # rmv_node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}RDF', nsmap=ns)
#
# <ipython-input-232-526ca6039201> in <listcomp>(.0)
#      25         for n in m[0]:
#      26             print(get_node_data(n))
# ---> 27 checked = [ check_author(node[0], node[1]) for node in mapped ]
#      28 # add_node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}RDF', nsmap=ns)
#      29 # rmv_node = ET.Element('{http://www.w3.org/1999/02/22-rdf-syntax-ns#}RDF', nsmap=ns)
#
# <ipython-input-229-ac42ed32fbcf> in check_author(node, data)
#       2     nd = [ get_node_data(n) for n in node ]
#       3     auths = [ n[1] for n in nd if n[0] == '{http://vivo.brown.edu/ontology/citation#}hasContributor']
# ----> 4     return data[0] in auths
#
# TypeError: 'bool' object is not subscriptable

# %%
qn = { 'rdf' : '{{{0}}}'.format(ns['rdf']), 'bcite' : '{{{0}}}'.format(ns['bcite']),
     'rdfs' : '{{{0}}}'.format(ns['rdfs']), 'vitro' : '{{{0}}}'.format(ns['vitro'])}
add_node = ET.Element(qn['rdf'] + "RDF", nsmap=ns)
rmv_node = ET.Element(qn['rdf'] + "RDF", nsmap=ns)

skip_tags = { qn['bcite']+'venueFor', qn['bcite']+'issn', qn['bcite']+'eissn',
            qn['vitro']+'mostSpecificType' }
venue_titles = { 'The 2005 IEEE Annual Conference Wireless and Micrwave Technology, 2005.',
               'The Johns Hopkins medical journal', 'Chemico-biological interactions',
               'Advances in prostaglandin, thromboxane, and leukotriene research',
               'Earth Moon Planet', 'Biocomputing 2012'}
skip_rsc = { ,
            'http://www.w3.org/2002/07/owl#Thing'}

nodes = root.findall('rdf:Description', ns)
for n in nodes:
    anode = ET.SubElement(add_node, qn['rdf'] + "Description")
    rnode = ET.SubElement(rmv_node, qn['rdf'] + "Description")
    rnode.set(qn['rdf']+'about', n.get(qn['rdf']+'about'))
    type_node = None
    noid_node = None
    spec_type = 'http://vivo.brown.edu/ontology/citation#Citation'
    for child in n:
        if child.tag not in skip_tags:
            rsc = child.get(qn['rdf']+'resource')
            if (rsc in skip_rsc or child.text in venue_titles):
                continue
            if (child.tag == qn['rdf'] + 'type'):
                if rsc == 'http://vivo.brown.edu/ontology/citation#NoID':
                    noid_node = deepcopy(child)
                    continue
                if spec_type == 'http://vivo.brown.edu/ontology/citation#Citation':
                    spec_type = child.get(qn['rdf']+'resource')
                    type_node = deepcopy(child)
                continue
            anode.append(deepcopy(child))
            rnode.append(deepcopy(child))
    anode.append(deepcopy(type_node))
    rnode.append(deepcopy(type_node))
    if noid_node is not None:
        rnode.append(noid_node)
